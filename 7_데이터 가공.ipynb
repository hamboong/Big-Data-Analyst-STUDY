# %% [raw]
# 2025.05.22

# %% [markdown]
# ## **데이터 가공**
# ### **▶*apply***
#
# - 행 또는 열 기준 복잡한 처리를 할 때 사용
# - 행 또는 열을 입력값으로 넣으면 행 또는 열에 반복적으로 수행
# - apply(함수, axis = 0 or 1) 형태로 사용
# - 람다 함수 : 즉시 정의하여 사용하는 익명 함수

# %% [markdown]
# ## **데이터 요약**
# ### **▶*Group by***
#
# - 엑셀의 pivot과 동일한 기능
# - 계층적 구조의 데이터 탐색에 유용

# %% [markdown]
# ## **Data : CAR_CRASHES 내장 데이터**
#
# ### **데이터 설명**
# - total: Number of drivers involved in fatal collisions per billion miles (5.900–23.900)
# - speeding: Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding (1.792–
# 9.450)
# - alcohol: Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired
# (1.593–10.038)
# - not_distracted: Percentage Of Drivers Involved In Fatal Collisions Who Were Not
# Distracted (1.760–23.661)
# - no_previous: Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been
# Involved In Any Previous Accidents (5.900–21.280)
# - ins_premium: Car Insurance Premiums (641.960–1301.520)
# - ins_losses: Losses incurred by insurance companies for collisions per insured driver
# (82.75–194.780)

# %% [markdown]
# ## **apply**

# %%
from seaborn import load_dataset
import numpy as np
import pandas as pd

# %% [markdown]
# ## **함수를 행 별로 반복 적용이 가능한 apply 함수**

# %%
car_df = load_dataset('car_crashes')
car_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
car_df[car_df['total']>20]
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 17   21.4     4.066    4.922          16.692       16.264       872.51
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 48   23.8     8.092    6.664          23.086       20.706       992.61
#
#     ins_losses abbrev
# 3       142.39     AR
# 17      137.13     KY
# 18      194.78     LA
# 26       85.15     MT
# 34      109.72     ND
# 40      116.29     SC
# 48      152.56     WV

# %%
def plue(x,y):
    x+y

# %%
car_df['alcohol'].apply(np.square).head(5) #np.square : 제곱함수
# Out:
# 0    31.809600
# 1    20.475625
# 2    27.123264
# 3    33.918976
# 4    11.289600
# Name: alcohol, dtype: float64

# %% [markdown]
# ## **lambda 함수 활용**
# - 익명 함수를 즉시 적용해 활용 가능

# %%
car_df.apply(lambda x:np.square(x)
            if x.name in ['alcohol', 'total'] else x).head(5)
# Out:
#     total  speeding    alcohol  not_distracted  no_previous  ins_premium  \
# 0  353.44     7.332  31.809600          18.048       15.040       784.55
# 1  327.61     7.421  20.475625          16.290       17.014      1053.48
# 2  345.96     6.510  27.123264          15.624       17.856       899.47
# 3  501.76     4.032  33.918976          21.056       21.280       827.34
# 4  144.00     4.200  11.289600          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
car_df[['total','speeding','alcohol']].apply(lambda x: x.max()-x.min())
# Out:
# total       18.000
# speeding     7.658
# alcohol      8.445
# dtype: float64

# %%
# 행 기준 적용하고 싶다면 axis = 1
car_df[['total','speeding','alcohol']].apply(
    lambda x: x.max() - x.min(), axis =1 ).head(5)
# Out:
# 0    13.160
# 1    13.575
# 2    13.392
# 3    18.368
# 4     8.640
# dtype: float64

# %%
car_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
car_df['alcohol'].apply(
    lambda x : np.square(x) if x>5 else x).head(5)
# Out:
# 0    31.809600
# 1     4.525000
# 2    27.123264
# 3    33.918976
# 4     3.360000
# Name: alcohol, dtype: float64

# %%
car_df['abbrev'].apply(
    lambda x: (x,x.count('A'))).head(10)
# Out:
# 0    (AL, 1)
# 1    (AK, 1)
# 2    (AZ, 1)
# 3    (AR, 1)
# 4    (CA, 1)
# 5    (CO, 0)
# 6    (CT, 0)
# 7    (DE, 0)
# 8    (DC, 0)
# 9    (FL, 0)
# Name: abbrev, dtype: object

# %%
def ac_score(x):
    if x>5:
        return 'bad'
    elif x> 3:
        return 'normal'
    else :
        return 'good'

car_df['alcohol'].apply(lambda x: ac_score(x)).head(10)
# Out:
# 0       bad
# 1    normal
# 2       bad
# 3       bad
# 4    normal
# 5    normal
# 6    normal
# 7    normal
# 8      good
# 9       bad
# Name: alcohol, dtype: object

# %%
new_car_df = car_df
new_car_df['ac_score'] = new_car_df['alcohol'].apply(
    lambda x : 'bad' if x >5 else ('normal' if x>3 else 'good'))
new_car_df.head(10)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev ac_score
# 0      145.08     AL      bad
# 1      133.93     AK   normal
# 2      110.35     AZ      bad
# 3      142.39     AR      bad
# 4      165.63     CA   normal
# 5      139.91     CO   normal
# 6      167.02     CT   normal
# 7      151.48     DE   normal
# 8      136.05     DC     good
# 9      144.18     FL      bad

# %% [markdown]
# ## **Group by 함수**
# - count : 행의 개수
# - sum : 값의 합
# - mean : 값의 평균
# - median : 값의 중앙값
# - prod : 값의 곱
# - first, last : 값들 중 첫 번째, 마지막 번 째 값
# - max, min
# - agg : 연산 함수와 동일한 효과
# - transform() : 함수의 결과값을 Data Frame에 Mapping

# %%
# new_car_df.groupby(['ac_score']).median() # 이거 오류남. 중앙값할려면 dtype이 숫자형이어야만함

# %%
new_car_df.groupby(['ac_score'])[new_car_df.select_dtypes(include='number').columns].median()
# Out:
#           total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# ac_score
# bad        19.1    6.7375    5.713          16.970       16.852      843.155
# good        8.9    2.1070    2.296           7.791        7.504      910.260
# normal     13.8    4.2000    4.080          12.328       12.375      869.850
#
#           ins_losses
# ac_score
# bad          143.285
# good         134.490
# normal       137.130

# %%
new_car_df.groupby(['ac_score']).count()
# Out:
#           total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# ac_score
# bad          20        20       20              20           20           20
# good          4         4        4               4            4            4
# normal       27        27       27              27           27           27
#
#           ins_losses  abbrev
# ac_score
# bad               20      20
# good               4       4
# normal            27      27

# %%
new_car_df.groupby(['ac_score'])[new_car_df.select_dtypes(include='number').columns].median()['total']
# Out:
# ac_score
# bad       19.1
# good       8.9
# normal    13.8
# Name: total, dtype: float64

# %%
new_car_df['median_by_alchol'] = new_car_df.groupby(
    ['ac_score'])['total'].transform('median')

# %%
new_car_df.groupby(['ac_score'])[new_car_df.select_dtypes(include='number').columns].agg('mean')
# Out:
#               total  speeding   alcohol  not_distracted  no_previous  \
# ac_score
# bad       19.395000  6.398600  6.474150       16.846450    17.150350
# good       8.750000  2.739750  2.263750        7.856500     7.939000
# normal    14.162963  4.295444  4.099556       11.995444    12.573556
#
#           ins_premium  ins_losses  median_by_alchol
# ac_score
# bad        865.914000  136.415500              19.1
# good       967.897500  128.627500               8.9
# normal     890.554444  133.938148              13.8
